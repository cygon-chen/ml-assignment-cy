# %%
import tkinter as tk
from PIL import Image, ImageTk
base = tk.Tk()
base.geometry("650x750")
base.attributes('-fullscreen',True)
#create Title
base.title("\"Can I Get You\" Predictor")
myImage=ImageTk.PhotoImage(Image.open("3.jpg"))
root=tk.Canvas(width=1000,height=1000)
root.pack(fill="both",expand=True)
root.create_image(0,0,image=myImage)

def destroy():
    base.destroy()
    
def callLine(frameNo):
    Labelline=tk.Label(framecollection[frameNo], text="-----------------------------------------------------------------------------------------------------------------------")
    Labelline.grid(column=0)
    
def createQuestions(integer,string,frameNo):
    callLine(frameNo)
    QuestionTitle=tk.Label(framecollection[frameNo], text="Question "+str(integer+1))
    QuestionTitle.grid(column=0)
    Question=tk.Label(framecollection[frameNo], text=string[integer],anchor='w',font="bold 12")
    Question.grid()

def enterData(dataposition, newdata,buttonNo,datasetNo):
    (dataset[datasetNo])[dataposition]=newdata
    button[buttonNo].config(state='disabled')
    if(dataposition==18):
        AnswerActType=tk.Label(framecollection[1+datasetNo*4],text="Your Answer is "+str(newdata)).grid(row=3)
    elif(dataposition==19):
        AnswerPersonType=tk.Label(framecollection[1+datasetNo*4],text="Your Answer is "+str(newdata)).grid(row=10)
    elif(dataposition==20):
        AnswerSenseOfCe=tk.Label(framecollection[1+datasetNo*4],text="Your Answer is "+str(newdata)).grid(row=18)
    elif(dataposition==49):
        AnswerEnjoy=tk.Label(framecollection[2+datasetNo*4],text="Your Answer is "+str(newdata)).grid(row=21)
    elif(dataposition==50):
        AnswerOrganized=tk.Label(framecollection[3+datasetNo*4],text="Your Answer is "+str(newdata)).grid(row=3)
    elif(dataposition==57):
        AnswerHowLong=tk.Label(framecollection[8],text="Your Answer is "+str(newdata)).grid(row=3)
    elif(dataposition==58):
        AnswerFriendship=tk.Label(framecollection[8],text="Your Answer is "+str(newdata)).grid(row=10)


def callSpace(frameNo):
    Space=tk.Label(framecollection[frameNo])
    Space.grid()

def nextPage(frame_number):
    global framecollection
    global button_forward
    global button_back
    global currentFrame
    
    currentFrame=currentFrame+1
    framecollection[frame_number-2].pack_forget()
    framecollection[frame_number-1].pack()
    if(currentFrame<8):
        button_forward=tk.Button(framecollection[frame_number-1], text=">>",command=lambda:nextPage(frame_number+1))
        button_forward.grid(row=30,column=0,sticky='e')
        button_forward.config(width=42,height=2)
    if(currentFrame==8):
        button_submit=tk.Button(framecollection[8],text="SUBMIT",command=lambda:nextPage(frame_number+1))
        button_submit.grid(row=30,column=0,sticky='e')
        button_submit.config(width=42,height=2)
    if(currentFrame<9):
        button_back=tk.Button(framecollection[frame_number-1], text="<<",command=lambda:previousPage(frame_number-1))
        button_back.grid(row=30,column=0,sticky='w')
        button_back.config(width=42,height=2)
    button_exit=tk.Button(framecollection[frame_number-1], text="Exit",command=destroy)
    button_exit.grid(row=31,column=0)
    button_exit.config(width=42,height=2)
    
def previousPage(frame_number):
    global framecollection
    global button_forward
    global button_back
    global currentFrame
    
    currentFrame=currentFrame-1
    framecollection[frame_number].pack_forget()
    framecollection[frame_number-1].pack()
    button_forward=tk.Button(framecollection[frame_number-1], text=">>",command=lambda:nextPage(frame_number+1))
    button_forward.grid(row=30,column=0,sticky='e')
    button_forward.config(width=42,height=2)
    button_back=tk.Button(framecollection[frame_number-1], text="<<",command=lambda:previousPage(frame_number-1))
    button_back.grid(row=30,column=0,sticky='w')
    button_back.config(width=42,height=2)
    button_exit=tk.Button(framecollection[frame_number-1], text="Exit",command=destroy)
    button_exit.grid(row=31,column=0)
    button_exit.config(width=42,height=2)
    if(frame_number==1):
        button_back.config(state="disabled")
    

def transferData():
    if(Race.get()=="Malay"):
        position=1
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==0):
            enterData(position,1,1,0)
        elif(currentFrame==4):
            enterData(position,1,16,1)
    elif(Race.get()=="Indian"):
        position=2
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==0):
            enterData(position,1,1,0)
        elif(currentFrame==4):
            enterData(position,1,16,1)
    elif(Race.get()=="Chinese"):
        position=3
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==0):
            enterData(position,1,1,0)
        elif(currentFrame==4):
            enterData(position,1,16,1)
    elif(Race.get()=="Sikh"):
        position=4
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==0):
            enterData(position,1,1,0)
        elif(currentFrame==4):
            enterData(position,1,16,1)
    elif(Race.get()=="Other"):
        position=5
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==0):
            enterData(position,1,1,0)
        elif(currentFrame==4):
            enterData(position,1,16,1)
    elif(Race.get()=="Don't know"):
        position=6
        AnswerRace=tk.Label(framecollection[currentFrame],text="Your Answer is "+Race.get()).grid(row=9)
        Race.set(" ")
        if(currentFrame==4):
            enterData(position,1,16,1)
    if(Religion.get()=="Islam"):
        position=7
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==0):
            enterData(position,1,2,0)
        elif(currentFrame==4):
            enterData(position,1,17,1)
    elif(Religion.get()=="Buddha"):
        position=8
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==0):
            enterData(position,1,2,0)
        elif(currentFrame==4):
            enterData(position,1,17,1)
    elif(Religion.get()=="Hindu"):
        position=9
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==0):
            enterData(position,1,2,0)
        elif(currentFrame==4):
            enterData(position,1,17,1)
    elif(Religion.get()=="Christian"):
        position=10
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==0):
            enterData(position,1,2,0)
        elif(currentFrame==4):
            enterData(position,1,17,1)
    elif(Religion.get()=="Other"):
        position=11
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==0):
            enterData(position,1,2,0)
        elif(currentFrame==4):
            enterData(position,1,17,1)
    elif(Religion.get()=="Don't know"):
        position=12
        AnswerReligion=tk.Label(framecollection[currentFrame],text="Your Answer is "+Religion.get()).grid(row=15)
        Religion.set(" ")
        if(currentFrame==4):
            enterData(position,1,17,1)
    if(Edu.get()=="Secondary School"):
        position=13
        AnswerEdu=tk.Label(framecollection[currentFrame],text="Your Answer is "+Edu.get()).grid(row=21)
        Edu.set(" ")
        if(currentFrame==0):
            enterData(position,1,3,0)
        elif(currentFrame==4):
            enterData(position,1,18,1)
    elif(Edu.get()=="Diploma"):
        position=14
        AnswerEdu=tk.Label(framecollection[currentFrame],text="Your Answer is "+Edu.get()).grid(row=21)
        Edu.set(" ")
        if(currentFrame==0):
            enterData(position,1,3,0)
        elif(currentFrame==4):
            enterData(position,1,18,1)
    elif(Edu.get()=="Undergraduate"):
        position=15
        AnswerEdu=tk.Label(framecollection[currentFrame],text="Your Answer is "+Edu.get()).grid(row=21)
        Edu.set(" ")
        if(currentFrame==0):
            enterData(position,1,3,0)
        elif(currentFrame==4):
            enterData(position,1,18,1)
    elif(Edu.get()=="Postgraduate"):
        position=16
        AnswerEdu=tk.Label(framecollection[currentFrame],text="Your Answer is "+Edu.get()).grid(row=21)
        Edu.set(" ")
        if(currentFrame==0):
            enterData(position,1,3,0)
        elif(currentFrame==4):
            enterData(position,1,18,1)
    elif(Edu.get()=="Don't know"):
        position=17
        AnswerEdu=tk.Label(framecollection[currentFrame],text="Your Answer is "+Edu.get()).grid(row=21)
        Edu.set(" ")
        if(currentFrame==4):
            enterData(position,1,18,1)
    if(Music.get()=="Pop Music"):
        position=21
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Classic Music"):
        position=22
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Rock Music"):
        position=23
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Country Music"):
        position=24
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Hip Hop Music"):
        position=25
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Other"):
        position=26
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==1):
            enterData(position,1,7,0)
        elif(currentFrame==5):
            enterData(position,1,22,1)
    elif(Music.get()=="Don't know"):
        position=27
        AnswerMusic=tk.Label(framecollection[currentFrame],text="Your Answer is "+Music.get()).grid(row=25)
        Music.set(" ")
        if(currentFrame==5):
            enterData(position,1,22,1)
    if(Movie.get()=="Science Fiction"):
        position=28
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Romance"):
        position=29
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Action"):
        position=30
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Horror"):
        position=31
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Adventure"):
        position=32
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Comedy"):
        position=33
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Mystery"):
        position=34
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Fantasy"):
        position=35
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Animation"):
        position=36
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Other"):
        position=37
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==2):
            enterData(position,1,8,0)
        elif(currentFrame==6):
            enterData(position,1,23,1)
    elif(Movie.get()=="Don't know"):
        position=38
        AnswerMovie=tk.Label(framecollection[currentFrame],text="Your Answer is "+Movie.get()).grid(row=3)
        Movie.set(" ")
        if(currentFrame==6):
            enterData(position,1,23,1)
    if(Travel.get()=="Solo (Self-tour)"):
        position=39
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==2):
            enterData(position,1,9,0)
        elif(currentFrame==6):
            enterData(position,1,24,1)
    elif(Travel.get()=="Solo (Package-tour)"):
        position=40
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==2):
            enterData(position,1,9,0)
        elif(currentFrame==6):
            enterData(position,1,24,1)
    elif(Travel.get()=="With friends"):
        position=41
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==2):
            enterData(position,1,9,0)
        elif(currentFrame==6):
            enterData(position,1,24,1)
    elif(Travel.get()=="With family"):
        position=42
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==2):
            enterData(position,1,9,0)
        elif(currentFrame==6):
            enterData(position,1,24,1)
    elif(Travel.get()=="Other"):
        position=43
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==2):
            enterData(position,1,9,0)
        elif(currentFrame==6):
            enterData(position,1,24,1)
    elif(Travel.get()=="Don't know"):
        position=44
        AnswerTravel=tk.Label(framecollection[currentFrame],text="Your Answer is "+Travel.get()).grid(row=9)
        Travel.set(" ")
        if(currentFrame==6):
            enterData(position,1,24,1)
    if(Plan.get()=="Plan almost everything of your future"):
        position=45
        AnswerPlan=tk.Label(framecollection[currentFrame],text="Your Answer is "+Plan.get()).grid(row=15)
        Plan.set(" ")
        if(currentFrame==2):
            enterData(position,1,10,0)
        elif(currentFrame==6):
            enterData(position,1,25,1)
    elif(Plan.get()=="Only plan the near future"):
        position=46
        AnswerPlan=tk.Label(framecollection[currentFrame],text="Your Answer is "+Plan.get()).grid(row=15)
        Plan.set(" ")
        if(currentFrame==2):
            enterData(position,1,10,0)
        elif(currentFrame==6):
            enterData(position,1,25,1)
    elif(Plan.get()=="Do not plan at all"):
        position=47
        AnswerPlan=tk.Label(framecollection[currentFrame],text="Your Answer is "+Plan.get()).grid(row=15)
        Plan.set(" ")
        if(currentFrame==2):
            enterData(position,1,10,0)
        elif(currentFrame==6):
            enterData(position,1,25,1)
    elif(Plan.get()=="Don't know"):
        position=48
        AnswerPlan=tk.Label(framecollection[currentFrame],text="Your Answer is "+Plan.get()).grid(row=15)
        Plan.set(" ")
        if(currentFrame==6):
            enterData(position,1,25,1)
    if(MorNight.get()=="Morning person"):
        position=51
        AnswerMorNight=tk.Label(framecollection[currentFrame],text="Your Answer is "+MorNight.get()).grid(row=10)
        MorNight.set(" ")
        if(currentFrame==3):
            enterData(position,1,13,0)
        elif(currentFrame==7):
            enterData(position,1,28,1)
    elif(MorNight.get()=="Night owl"):
        position=52
        AnswerMorNight=tk.Label(framecollection[currentFrame],text="Your Answer is "+MorNight.get()).grid(row=10)
        MorNight.set(" ")
        if(currentFrame==3):
            enterData(position,1,13,0)
        elif(currentFrame==7):
            enterData(position,1,28,1)
    elif(MorNight.get()=="Don't know"):
        position=53
        AnswerMorNight=tk.Label(framecollection[currentFrame],text="Your Answer is "+MorNight.get()).grid(row=10)
        MorNight.set(" ")
        if(currentFrame==7):
            enterData(position,1,28,1)
    if(Gift.get()=="Expensive gifts"):
        position=54
        AnswerGift=tk.Label(framecollection[currentFrame],text="Your Answer is "+Gift.get()).grid(row=16)
        Gift.set(" ")
        if(currentFrame==3):
            enterData(position,1,14,0)
        elif(currentFrame==7):
            enterData(position,1,29,1)
    elif(Gift.get()=="Sentimental gifts"):
        position=55
        AnswerGift=tk.Label(framecollection[currentFrame],text="Your Answer is "+Gift.get()).grid(row=16)
        Gift.set(" ")
        if(currentFrame==3):
            enterData(position,1,14,0)
        elif(currentFrame==7):
            enterData(position,1,29,1)
    elif(Gift.get()=="Don't know"):
        position=56
        AnswerGift=tk.Label(framecollection[currentFrame],text="Your Answer is "+Gift.get()).grid(row=16)
        Gift.set(" ")
        if(currentFrame==7):
            enterData(position,1,29,1)
            
currentFrame=0
data=[0]*57
data2=[0]*57
data3=[0]*59
dataset=[]
dataset.append(data)
dataset.append(data2)
dataset.append(data3)
button=[]
framecollection=[]

#create Instruction
InstrucLabel=tk.Label(root, text="Please answer the following questions:")
InstrucLabel.pack()

#create Frame
frame=tk.LabelFrame(root, text="About Yourself...", padx=10, pady=10)
framecollection.append(frame)
frame.pack()
frame2=tk.LabelFrame(root, text="About Yourself...", padx=10, pady=10)
framecollection.append(frame2)
frame3=tk.LabelFrame(root, text="About Yourself...", padx=10, pady=10)
framecollection.append(frame3)
frame4=tk.LabelFrame(root, text="About Yourself...", padx=10, pady=10)
framecollection.append(frame4)
frame5=tk.LabelFrame(root, text="About Your Loved One...", padx=10, pady=10)
framecollection.append(frame5)
frame6=tk.LabelFrame(root, text="About Your Loved One...", padx=10, pady=10)
framecollection.append(frame6)
frame7=tk.LabelFrame(root, text="About Your Loved One...", padx=10, pady=10)
framecollection.append(frame7)
frame8=tk.LabelFrame(root, text="About Your Loved One...", padx=10, pady=10)
framecollection.append(frame8)
frame9=tk.LabelFrame(root, text="Last part...", padx=10, pady=10)
framecollection.append(frame9)
frame10=tk.LabelFrame(root, text="About Your Loved One...", padx=10, pady=10)
framecollection.append(frame10)


#Creating Questions
Questions=["Your Age", "Your Race", "Your Religion", "Your Education Level", "Type of activities that you prefer"
          , "Rate your personality", "Do you care about the sense of ceremony?",
          "What kind of music genre do you like?","What kind of movie genre do you like?","What type of travelling do you prefer",
          "Which of the following best describes you?","Do you enjoy challenges in life?", "Are you an organized person?", "Are you a morning person or a night owl?",
          "Do you prefer expensive gifts or sentimental ones?"]

Questions2=["The age of the one you confessed to (Approximate if you don't know)", "His/Her Race", "His/Her Religion", 
            "His/Her Education Level", "Type of activities that he/she prefers"
          , "Rate his/her personality", "Does he/she care about the sense of ceremony?",
          "What kind of music genre does he/she like?","What kind of movie genre does he/she like?","What type of travelling does he/she prefer",
          "Which of the following best describes him/her?","Does he/she enjoy challenges in life?", "Is him/her an organized person?", "Is him/her a morning person or a night owl?",
          "Does he/she prefer expensive gifts or sentimental ones?"]

Questions3=["How long have you been friends with him/her? (in years)","How would you rate the friendship with him/her?"]

for i in range (0,4):
    createQuestions(i,Questions,0)
    
    if(i==0):
        e=tk.Entry(frame, width=50)
        e.grid() 
        Button=tk.Button(frame, text="Enter",command=lambda:enterData(0,int(e.get()),0,0))
        button.append(Button)
        Button.grid()
        callSpace(0)
    
    if(i==1):
        Race=tk.StringVar()
        RaceList=tk.OptionMenu(frame,Race,"Malay","Indian","Chinese","Sikh","Other")
        RaceList.config(width=50,font="bold")
        RaceList.grid()
        Button=tk.Button(frame, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(0)
    
    if(i==2):
        Religion=tk.StringVar()
        drop=tk.OptionMenu(frame,Religion,"Islam","Buddha","Hindu","Christian","Other")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(0)
    
    if(i==3):
        Edu=tk.StringVar()
        drop=tk.OptionMenu(frame,Edu,"Secondary School","Diploma","Undergraduate","Postgraduate")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(0)

for i in range (4,8):
    createQuestions(i,Questions,1)
    
    if(i==4):
        ActType=tk.Scale(frame2,from_=1,to=5,orient='horizontal')
        ActType.grid()
        InOutLabel=tk.Label(frame2,text="Indoor--------------Outdoor")
        InOutLabel.grid()
        Button=tk.Button(frame2, text="Enter",command=lambda:enterData(18,ActType.get(),4,0))
        button.append(Button)
        Button.grid()
        callSpace(1)
    
    if(i==5):
        PersonType=tk.Scale(frame2,from_=1,to=5,orient='horizontal')
        PersonType.grid()
        InExLabel=tk.Label(frame2,text="Introvert--------------Extrovert")
        InExLabel.grid()
        Button=tk.Button(frame2, text="Enter",command=lambda:enterData(19,PersonType.get(),5,0))
        button.append(Button)
        Button.grid()
        callSpace(1)
    
    if(i==6):
        SenseOfCeExample=tk.Label(frame2,text="(e.g. Valentine's Day, Anniversary, Birthday)").grid()
        SenseOfCe=tk.Scale(frame2,from_=1,to=5,orient='horizontal')
        SenseOfCe.grid()
        Degree=tk.Label(frame2,text="Not at all--------------Very Much")
        Degree.grid()
        Button=tk.Button(frame2, text="Enter",command=lambda:enterData(20,SenseOfCe.get(),6,0))
        button.append(Button)
        Button.grid()
        callSpace(1)
    
    if(i==7):
        Music=tk.StringVar()
        drop=tk.OptionMenu(frame2,Music,"Pop Music","Classic Music","Rock Music","Country Music",
                           "Hip Hop Music","Other")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame2, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(1)

for i in range (8,12):
    createQuestions(i,Questions,2)
    
    if(i==8):
        Movie=tk.StringVar()
        drop=tk.OptionMenu(frame3,Movie,"Science Fiction","Romance","Action","Horror","Adventure",
                           "Comedy","Mystery","Fantasy","Animation","Other")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame3, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(2)
    
    if(i==9):
        Travel=tk.StringVar()
        drop=tk.OptionMenu(frame3,Travel,"Solo (Self-tour)","Solo (Package-tour)","With friends",
                           "With family","Other")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame3, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(2)
    
    if(i==10):
        Plan=tk.StringVar()
        drop=tk.OptionMenu(frame3,Plan,"Plan almost everything of your future","Only plan the near future",
                           "Do not plan at all")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame3, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(2)
    
    if(i==11):
        Enjoy=tk.Scale(frame3,from_=1,to=5,orient='horizontal')
        Enjoy.grid()
        Degree=tk.Label(frame3,text="Strongly disagree--------------Strongly agree")
        Degree.grid()
        Button=tk.Button(frame3, text="Enter",command=lambda:enterData(49,Enjoy.get(),11,0))
        button.append(Button)
        Button.grid()
        callSpace(2)

for i in range (12,15):
    createQuestions(i,Questions,3)
    
    if(i==12):
        Organized=tk.Scale(frame4,from_=1,to=5,orient='horizontal')
        Organized.grid()
        Degree=tk.Label(frame4,text="Strongly disagree--------------Strongly agree")
        Degree.grid()
        Button=tk.Button(frame4, text="Enter",command=lambda:enterData(50,Organized.get(),12,0))
        button.append(Button)
        Button.grid()
        callSpace(3)
    
    if(i==13):
        MorNight=tk.StringVar()
        drop=tk.OptionMenu(frame4,MorNight,"Morning person","Night owl")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame4, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(3)
    
    if(i==14):
        Gift=tk.StringVar()
        drop=tk.OptionMenu(frame4,Gift,"Expensive gifts","Sentimental gifts")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame4, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(3)

for i in range (0,4):
        
    createQuestions(i,Questions2,4)
    if(i==0):
        e2=tk.Entry(frame5, width=50)
        e2.grid() 
        Button=tk.Button(frame5, text="Enter",command=lambda:enterData(0,int(e2.get()),15,1))
        button.append(Button)
        Button.grid()
        callSpace(4)
    
    if(i==1):
        RaceList=tk.OptionMenu(frame5,Race,"Malay","Indian","Chinese","Sikh","Other","Don't know")
        RaceList.config(width=50,font="bold")
        RaceList.grid()
        Button=tk.Button(frame5, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(4)
    
    if(i==2):
        drop=tk.OptionMenu(frame5,Religion,"Islam","Buddha","Hindu","Christian","Other","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame5, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(4)
    
    if(i==3):
        drop=tk.OptionMenu(frame5,Edu,"Secondary School","Diploma","Undergraduate","Postgraduate","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame5, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(4)
    
    if(i==3):
        Hint=tk.Label(frame5, text="Hint: Choose 3 for any Scaling questions that you don't know the value").grid()
        


for i in range (4,8):
    createQuestions(i,Questions2,5)
   
    if(i==4):
        ActType2=tk.Scale(frame6,from_=1,to=5,orient='horizontal')
        ActType2.grid()
        InOutLabel=tk.Label(frame6,text="Indoor--------------Outdoor")
        InOutLabel.grid()
        Button=tk.Button(frame6, text="Enter",command=lambda:enterData(18,ActType2.get(),19,1))
        button.append(Button)
        Button.grid()
        callSpace(5)
    
    
    if(i==5):
        PersonType2=tk.Scale(frame6,from_=1,to=5,orient='horizontal')
        PersonType2.grid()
        InExLabel=tk.Label(frame6,text="Introvert--------------Extrovert")
        InExLabel.grid()
        Button=tk.Button(frame6, text="Enter",command=lambda:enterData(19,PersonType2.get(),20,1))
        button.append(Button)
        Button.grid()
        callSpace(5)
    
    if(i==6):
        SenseOfCeExample2=tk.Label(frame6,text="(e.g. Valentine's Day, Anniversary, Birthday)").grid()
        SenseOfCe2=tk.Scale(frame6,from_=1,to=5,orient='horizontal')
        SenseOfCe2.grid()
        Degree=tk.Label(frame6,text="Not at all--------------Very Much")
        Degree.grid()
        Button=tk.Button(frame6, text="Enter",command=lambda:enterData(20,SenseOfCe2.get(),21,1))
        button.append(Button)
        Button.grid()
        callSpace(5)
    
    if(i==7):
        drop=tk.OptionMenu(frame6,Music,"Pop Music","Classic Music","Rock Music","Country Music",
                           "Hip Hop Music","Other","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame6, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(5)

for i in range (8,12):
    createQuestions(i,Questions2,6)
    
    if(i==8):
        drop=tk.OptionMenu(frame7,Movie,"Science Fiction","Romance","Action","Horror","Adventure",
                           "Comedy","Mystery","Fantasy","Animation","Other","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame7, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(6)
    
    if(i==9):
        drop=tk.OptionMenu(frame7,Travel,"Solo (Self-tour)","Solo (Package-tour)","With friends",
                           "With family","Other","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame7, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(6)
    
    if(i==10):
        drop=tk.OptionMenu(frame7,Plan,"Plan almost everything of your future","Only plan the near future",
                           "Do not plan at all","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame7, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(6)
    
    if(i==11):
        Enjoy2=tk.Scale(frame7,from_=1,to=5,orient='horizontal')
        Enjoy2.grid()
        Degree=tk.Label(frame7,text="Strongly disagree--------------Strongly agree")
        Degree.grid()
        Button=tk.Button(frame7, text="Enter",command=lambda:enterData(49,Enjoy2.get(),26,1))
        button.append(Button)
        Button.grid()
        callSpace(6)

for i in range (12,15):
    createQuestions(i,Questions2,7)
    
    if(i==12):
        Organized2=tk.Scale(frame8,from_=1,to=5,orient='horizontal')
        Organized2.grid()
        Degree=tk.Label(frame8,text="Strongly disagree--------------Strongly agree")
        Degree.grid()
        Button=tk.Button(frame8, text="Enter",command=lambda:enterData(50,Organized2.get(),27,1))
        button.append(Button)
        Button.grid()
        callSpace(7)
    
    if(i==13):
        drop=tk.OptionMenu(frame8,MorNight,"Morning person","Night owl","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame8, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(7)
    
    if(i==14):
        drop=tk.OptionMenu(frame8,Gift,"Expensive gifts","Sentimental gifts","Don't know")
        drop.config(width=50,font="bold")
        drop.grid()
        Button=tk.Button(frame8, text="Enter",command=transferData)
        button.append(Button)
        Button.grid()
        callSpace(7)

for i in range (0,2):
    createQuestions(i,Questions3,8)
    
    if(i==0):
        Howlong=tk.Scale(frame9,from_=0,to=50,orient='horizontal')
        Howlong.grid()
        Years=tk.Label(frame9,text="years")
        Years.grid()
        Button=tk.Button(frame9, text="Enter",command=lambda:enterData(57,Howlong.get(),30,2))
        button.append(Button)
        Button.grid()
        callSpace(8)
        
    if(i==1):
        Friendship=tk.Scale(frame9,from_=0,to=5,orient='horizontal')
        Friendship.grid()
        Degree=tk.Label(frame9,text="Strangers--------------Very close")
        Degree.grid()
        Button=tk.Button(frame9, text="Enter",command=lambda:enterData(58,Friendship.get(),30,2))
        button.append(Button)
        Button.grid()
        callSpace(8)

button_back=tk.Button(frame, text="<<",command=lambda:previousPage(),state="disabled")
button_back.grid(row=30,column=0,sticky='w')
button_back.config(width=42,height=2)
button_forward=tk.Button(frame, text=">>",command=lambda:nextPage(2))
button_forward.grid(row=30,column=0,sticky='e')
button_forward.config(width=42,height=2)
button_exit=tk.Button(frame, text="Exit",command=destroy)
button_exit.grid(row=31,column=0)
button_exit.config(width=42,height=2)
root.mainloop()
for i in range(57):
    data3[i]=data[i]+data2[i]
